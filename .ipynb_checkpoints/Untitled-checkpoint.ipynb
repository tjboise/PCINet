# %%
import pandas as pd
import matplotlib.pyplot as plt

dark_red = [210/255,0,0]
light_red = [228/255,128/255,128/255]

dark_blue = [71/255,55/255,63/255]
light_blue = [154/255,153/255,183/255]

dark_purple = [92/255,35/255,102/255]
light_purple = [158/255,124/255,163/255]

# Load the data from an Excel file
file_path = 'results.xlsx'  # Replace with your file path
sheet_name = 'Sheet3'  # Assuming the data is in Sheet 2
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Extract necessary columns
model_names = data.iloc[:, 0]  # First column: Model Names
mean_mse = data.iloc[:, 4]  # Second column: Mean MSE
std_mse = data.iloc[:, 8]  # Fourth column: Std of MSE

# Create a plot with error bars
plt.figure(figsize=(8, 5))
plt.bar(model_names, mean_mse, yerr=std_mse, capsize=5,color=light_blue)
plt.xlabel('Model')
plt.ylabel(r'$R^2$')
# plt.title('Mean MSE of Models with Error Bars for Std of MSE')
plt.xticks(rotation=45)  # Rotate model names for better visibility
plt.tight_layout()  # Adjust layout to make room for label rotation

plt.savefig('r2.png',dpi=600,bbox_inches = 'tight')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data from the uploaded Excel file
file_path = 'results.xlsx'  # File path
sheet_name = 'Sheet3'  # Assuming the data is in Sheet 2
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Extract necessary columns
model_names = data.iloc[:, 0]  # First column: Model Names
mean_mse = data.iloc[:, 2]  # Second column: Mean MSE
std_mse = data.iloc[:, 6]  # Fourth column: Std of MSE

# Define specific model groups based on your requirements
model_groups = {
    'Resnet': ['Resnet18', 'Resnet34', 'Resnet50'],
    'Yolov8': ['yolov8-m', 'yolov8-n', 'yolov8-s', 'yolov8-x'],
    'Mobilenet': ['Mobilenetv2', 'Mobilenetv3']
}

# Assign each model to a group, defaulting to the model's own name if not listed in the predefined groups
group_mapping = {model: group for group, models in model_groups.items() for model in models}
data['Group'] = model_names.map(lambda x: group_mapping.get(x, x))

# Group data based on the new 'Group' column
grouped_data = data.groupby('Group')

# Plotting
plt.figure(figsize=(8, 6))
colors = plt.cm.viridis(np.linspace(0, 1, len(grouped_data)))

for (group, group_data), color in zip(grouped_data, colors):
    plt.errorbar(group_data[model_names.name], group_data[mean_mse.name], yerr=group_data[std_mse.name], fmt='o-', capsize=5, label=group, color=color)

plt.xlabel('Model')
plt.ylabel('MAPE')
# plt.title('Log of Mean MSE of Models with Error Bars and Lines for Std of MSE')
plt.yscale('log')
plt.xticks(rotation=45)
plt.tight_layout()

plt.savefig('MAPE.png',dpi=600,bbox_inches = 'tight')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data from the uploaded Excel file
file_path = 'results.xlsx'  # File path
sheet_name = 'Sheet3'  # Assuming the data is in Sheet 3
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Extract necessary columns
model_names = data.iloc[:, 0]  # First column: Model Names
mean_mse = data.iloc[:, 2]  # Third column: Mean MSE
std_mse = data.iloc[:, 6]  # Seventh column: Std of MSE

# Define specific model groups based on your requirements
model_groups = {
    'Resnet': ['Resnet18', 'Resnet34', 'Resnet50'],
    'Yolov8': ['yolov8-m', 'yolov8-n', 'yolov8-s', 'yolov8-x'],
    'Mobilenet': ['Mobilenetv2', 'Mobilenetv3']
}

# Assign each model to a group, defaulting to the model's own name if not listed in the predefined groups
group_mapping = {model: group for group, models in model_groups.items() for model in models}
data['Group'] = model_names.map(lambda x: group_mapping.get(x, x))

# Group data based on the new 'Group' column
grouped_data = data.groupby('Group')

# Define specific colors for each group
color_mapping = {
    'Resnet': 'red',
    'Yolov8': 'blue',
    'Mobilenet': 'green'
}

# If there are groups not predefined, assign them random colors from a predefined list
additional_colors = ['orange', 'purple', 'brown', 'pink', 'gray']
additional_groups = [group for group in grouped_data.groups.keys() if group not in color_mapping]
for i, group in enumerate(additional_groups):
    color_mapping[group] = additional_colors[i % len(additional_colors)]

# Plotting
plt.figure(figsize=(8, 6))

for group, group_data in grouped_data:
    plt.errorbar(group_data[model_names.name], group_data[mean_mse.name], yerr=group_data[std_mse.name],
                 fmt='o-', capsize=5, label=group, color=color_mapping.get(group, 'black'))

plt.xlabel('Model')
plt.ylabel('MAPE')
plt.yscale('log')
plt.xticks(rotation=45)
plt.tight_layout()
# plt.legend()
plt.savefig('MAPE.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data from the uploaded Excel file
file_path = 'results.xlsx'  # File path
sheet_name = 'Sheet3'  # Assuming the data is in Sheet 2
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Extract necessary columns
model_names = data.iloc[:, 0]  # First column: Model Names
mean_mse = data.iloc[:, 3]  # Second column: Mean MSE
std_mse = data.iloc[:, 7]  # Fourth column: Std of MSE

# Define specific model groups based on your requirements
model_groups = {
    'Resnet': ['Resnet18', 'Resnet34', 'Resnet50'],
    'Yolov8': ['yolov8-m', 'yolov8-n', 'yolov8-s', 'yolov8-x'],
    'Mobilenet': ['Mobilenetv2', 'Mobilenetv3']
}

# Assign each model to a group, defaulting to the model's own name if not listed in the predefined groups
group_mapping = {model: group for group, models in model_groups.items() for model in models}
data['Group'] = model_names.map(lambda x: group_mapping.get(x, x))

# Group data based on the new 'Group' column
grouped_data = data.groupby('Group')

# Define specific colors for each group
color_mapping = {
    'Resnet': 'red',
    'Yolov8': 'blue',
    'Mobilenet': 'green'
}

# If there are groups not predefined, assign them random colors from a predefined list
additional_colors = ['orange', 'purple', 'brown', 'pink', 'gray']
additional_groups = [group for group in grouped_data.groups.keys() if group not in color_mapping]
for i, group in enumerate(additional_groups):
    color_mapping[group] = additional_colors[i % len(additional_colors)]

# Plotting
plt.figure(figsize=(8, 6))

for group, group_data in grouped_data:
    plt.errorbar(group_data[model_names.name], group_data[mean_mse.name], yerr=group_data[std_mse.name],
                 fmt='o-', capsize=5, label=group, color=color_mapping.get(group, 'black'))
plt.xlabel('Model')
plt.ylabel('MAE')
# plt.title('Log of Mean MSE of Models with Error Bars and Lines for Std of MSE')
# plt.yscale('log')
plt.xticks(rotation=45)
plt.tight_layout()
# plt.legend(title='Model Group')
plt.savefig('MAE.png',dpi=600,bbox_inches = 'tight')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data from the uploaded Excel file
file_path = 'results.xlsx'  # File path
sheet_name = 'Sheet3'  # Assuming the data is in Sheet 2
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Extract necessary columns
model_names = data.iloc[:, 0]  # First column: Model Names
mean_mse = data.iloc[:, 4]  # Second column: Mean MSE
std_mse = data.iloc[:, 8]  # Fourth column: Std of MSE

# Define specific model groups based on your requirements
model_groups = {
    'Resnet': ['Resnet18', 'Resnet34', 'Resnet50'],
    'Yolov8': ['yolov8-m', 'yolov8-n', 'yolov8-s', 'yolov8-x'],
    'Mobilenet': ['Mobilenetv2', 'Mobilenetv3']
}

# Assign each model to a group, defaulting to the model's own name if not listed in the predefined groups
group_mapping = {model: group for group, models in model_groups.items() for model in models}
data['Group'] = model_names.map(lambda x: group_mapping.get(x, x))

# Group data based on the new 'Group' column
grouped_data = data.groupby('Group')

# Define specific colors for each group
color_mapping = {
    'Resnet': 'red',
    'Yolov8': 'blue',
    'Mobilenet': 'green'
}

# If there are groups not predefined, assign them random colors from a predefined list
additional_colors = ['orange', 'purple', 'brown', 'pink', 'gray']
additional_groups = [group for group in grouped_data.groups.keys() if group not in color_mapping]
for i, group in enumerate(additional_groups):
    color_mapping[group] = additional_colors[i % len(additional_colors)]

# Plotting
plt.figure(figsize=(8, 6))

for group, group_data in grouped_data:
    plt.errorbar(group_data[model_names.name], group_data[mean_mse.name], yerr=group_data[std_mse.name],
                 fmt='o-', capsize=5, label=group, color=color_mapping.get(group, 'black'))
plt.xlabel('Model')
plt.ylabel(r'$R^2$')
# plt.title('Log of Mean MSE of Models with Error Bars and Lines for Std of MSE')
# plt.yscale('log')
plt.xticks(rotation=45)
plt.tight_layout()
# plt.legend(title='Model Group')
plt.savefig('R2.png',dpi=600,bbox_inches = 'tight')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data from the uploaded Excel file
file_path = 'results.xlsx'  # File path
sheet_name = 'Sheet3'  # Assuming the data is in Sheet 2
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Extract necessary columns
model_names = data.iloc[:, 0]  # First column: Model Names
mean_mse = data.iloc[:, 1]  # Second column: Mean MSE
std_mse = data.iloc[:, 5]  # Fourth column: Std of MSE

# Define specific model groups based on your requirements
model_groups = {
    'Resnet': ['Resnet18', 'Resnet34', 'Resnet50'],
    'Yolov8': ['yolov8-m', 'yolov8-n', 'yolov8-s', 'yolov8-x'],
    'Mobilenet': ['Mobilenetv2', 'Mobilenetv3']
}

# Assign each model to a group, defaulting to the model's own name if not listed in the predefined groups
group_mapping = {model: group for group, models in model_groups.items() for model in models}
data['Group'] = model_names.map(lambda x: group_mapping.get(x, x))

# Group data based on the new 'Group' column
grouped_data = data.groupby('Group')

# Define specific colors for each group
color_mapping = {
    'Resnet': 'red',
    'Yolov8': 'blue',
    'Mobilenet': 'green'
}

# If there are groups not predefined, assign them random colors from a predefined list
additional_colors = ['orange', 'purple', 'brown', 'pink', 'gray']
additional_groups = [group for group in grouped_data.groups.keys() if group not in color_mapping]
for i, group in enumerate(additional_groups):
    color_mapping[group] = additional_colors[i % len(additional_colors)]

# Plotting
plt.figure(figsize=(8, 6))

for group, group_data in grouped_data:
    plt.errorbar(group_data[model_names.name], group_data[mean_mse.name], yerr=group_data[std_mse.name],
                 fmt='o-', capsize=5, label=group, color=color_mapping.get(group, 'black'))
plt.xlabel('Model')
plt.ylabel('MSE')
# plt.title('Log of Mean MSE of Models with Error Bars and Lines for Std of MSE')
# plt.yscale('log')
plt.xticks(rotation=45)
plt.tight_layout()
# plt.legend(title='Model Group')
plt.savefig('MSE.png',dpi=600,bbox_inches = 'tight')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define colors
dark_red = [210/255, 0, 0]
light_red = [228/255, 128/255, 128/255]

dark_blue = [71/255, 55/255, 63/255]
light_blue = [154/255, 153/255, 183/255]

dark_purple = [92/255, 35/255, 102/255]
light_purple = [158/255, 124/255, 163/255]

# Load the data from an Excel file
file_path = 'results.xlsx'  # Replace with your file path
sheet_name = 'Sheet3'  # Adjust as per actual sheet name
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Extract necessary columns
model_names = data.iloc[:, 0]
mean_mse_bottom = data.iloc[:, 1]  # Mean MSE 
std_mse_bottom = data.iloc[:, 5]  # Std of MSE 

mean_mse_upper = data.iloc[:, 2]  # Mean MAPE
std_mse_upper = data.iloc[:, 6]  # Std of MSE for the upper bar

mean_mse_top = data.iloc[:, 3]  # Mean MAE
std_mse_top = data.iloc[:, 7] 

# Positioning the bars
bar_width = 0.75  # Width of the bars
index = np.arange(len(model_names))  # Positioning index for the models

# Create the plot
plt.figure()
primary_bars = plt.bar(index, mean_mse_bottom, bar_width,  capsize=5, color=light_blue, label='MSE')
# Add the secondary bars on top of the primary bars
secondary_bars = plt.bar(index, mean_mse_upper, bar_width, bottom=mean_mse_bottom,  capsize=5, color=light_red, label='MAPE')
top_bars = plt.bar(index, mean_mse_top, bar_width, bottom=mean_mse_upper,  capsize=5, color=light_red, label='MAE')
# Adding labels, title and custom x-axis labels, etc.
plt.xlabel('Model')
plt.ylabel('PCI error')
plt.xticks(index, model_names, rotation=45)
plt.legend()

# Layout adjustment
plt.tight_layout()
plt.yscale('log')
# Save the plot
plt.savefig('stacked_bars.png', dpi=300, bbox_inches='tight')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define colors
dark_red = [210/255, 0, 0]
light_red = [228/255, 128/255, 128/255]

dark_blue = [71/255, 55/255, 63/255]
light_blue = [154/255, 153/255, 183/255]

dark_purple = [92/255, 35/255, 102/255]
light_purple = [158/255, 124/255, 163/255]

# Load the data from an Excel file
file_path = 'results.xlsx'  # Replace with your file path
sheet_name = 'Sheet3'  # Adjust as per actual sheet name
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Extract necessary columns
model_names = data.iloc[:, 0]
mean_mse = data.iloc[:, 1]  # Mean MSE 
std_mse = data.iloc[:, 5]  # Std of MSE 

mean_mape = data.iloc[:, 2]  # Mean MAPE
std_mape = data.iloc[:, 6]  # Std of MAPE

mean_mae = data.iloc[:, 3]  # Mean MAE
std_mae = data.iloc[:, 7]  # Std of MAE

# Positioning the bars
bar_width = 0.75  # Width of the bars
index = np.arange(len(model_names))  # Positioning index for the models
# Define hatch patterns for each bar group
hatches = ['o', '.', 'x', '+']  # Different hatches for MAE, MAPE, MSE, R2
# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))

# Plot the MSE bars at the bottom
bars1 = ax.bar(index, mean_mse/3, bar_width, yerr=std_mse/3, capsize=5, color=light_blue,ecolor=dark_blue, label='MSE', hatch=hatches[2])

# Plot the MAPE bars stacked on top of the MSE bars
bars2 = ax.bar(index, mean_mape/3, bar_width, yerr=std_mape/3, bottom=mean_mse/3, capsize=5, color=light_red,ecolor=dark_red, label='MAPE', hatch=hatches[1])

# Plot the MAE bars stacked on top of the MAPE bars
bars3 = ax.bar(index, mean_mae/3, bar_width, yerr=std_mae/3, bottom=mean_mse/3+mean_mape/3, capsize=5, color=light_purple,ecolor=dark_purple, label='MAE', hatch=hatches[0])

# Adding labels, title and custom x-axis labels, etc.
ax.set_xlabel('Model')
ax.set_ylabel('PCI error')
ax.set_xticks(index)
ax.set_xticklabels(model_names, rotation=45)
ax.legend()

# Layout adjustment
plt.tight_layout()
plt.yscale('log')

# Save the plot
plt.savefig('stacked_bars.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define colors
dark_red = [210/255, 0, 0]
light_red = [228/255, 128/255, 128/255]

dark_blue = [71/255, 55/255, 63/255]
light_blue = [154/255, 153/255, 183/255]

dark_purple = [92/255, 35/255, 102/255]
light_purple = [158/255, 124/255, 163/255]

# Load the data from an Excel file
file_path = 'results.xlsx'  # Replace with your file path
sheet_name = 'Sheet3'  # Adjust as per actual sheet name
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Extract necessary columns
model_names = data.iloc[:, 0]
mean_mse = data.iloc[:, 1]
std_mse = data.iloc[:, 5]

mean_mape = data.iloc[:, 2]
std_mape = data.iloc[:, 6]

mean_mae = data.iloc[:, 3]
std_mae = data.iloc[:, 7]

# Min-Max Scaling for each error type
scaled_mse = (mean_mse - mean_mse.min()) / (mean_mse.max() - mean_mse.min())
scaled_mape = (mean_mape - mean_mape.min()) / (mean_mape.max() - mean_mape.min())
scaled_mae = (mean_mae - mean_mae.min()) / (mean_mae.max() - mean_mae.min())


# Scale standard deviations as well for the error bars
scaled_std_mse = std_mse / (mean_mse.max() - mean_mse.min())
scaled_std_mape = std_mape / (mean_mape.max() - mean_mape.min())
scaled_std_mae = std_mae / (mean_mae.max() - mean_mae.min())

# Positioning the bars
bar_width = 0.75  # Width of the bars
index = np.arange(len(model_names))  # Positioning index for the models
# Define hatch patterns for each bar group
hatches = ['o', '.', 'x']  # Different hatches for MAE, MAPE, MSE

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))

# Plot the MSE bars at the bottom
bars1 = ax.bar(index, scaled_mse / 3, bar_width, yerr=scaled_std_mse / 3, capsize=5, color=light_blue, ecolor=dark_blue, label='scaled MSE', hatch=hatches[2])

# Plot the MAPE bars stacked on top of the MSE bars
bars2 = ax.bar(index, scaled_mape / 3, bar_width, yerr=scaled_std_mape / 3, bottom=scaled_mse / 3, capsize=5, color=light_red, ecolor=dark_red, label='scaled MAPE', hatch=hatches[1])

# Plot the MAE bars stacked on top of the MAPE bars
bars3 = ax.bar(index, scaled_mae / 3, bar_width, yerr=scaled_std_mae / 3, bottom=scaled_mse / 3 + scaled_mape / 3, capsize=5, color=light_purple, ecolor=dark_purple, label='scaled MAE', hatch=hatches[0])

print(scaled_mae/3+scaled_mse / 3 + scaled_mape / 3)
# Adding labels, title and custom x-axis labels, etc.
ax.set_xlabel('Model')
ax.set_ylabel('PCI Error')
ax.set_xticks(index)
ax.set_xticklabels(model_names, rotation=45)
ax.legend()
plt.ylim(0,1)

# Layout adjustment
plt.tight_layout()
# plt.yscale('log')

# Save the plot
plt.savefig('scaled_stacked_bars.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 0     0.551429
# 1     0.587254
# 2     0.620462
# 3     0.828626
# 4     0.241674
# 5     0.327903
# 6     0.578851
# 7     0.387755
# 8     0.505609
# 9     0.439134
# 10    0.469961
# 11    0.000000
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

dark_red = [210/255,0,0]
light_red = [228/255,128/255,128/255]

dark_blue = [71/255,55/255,63/255]
light_blue = [154/255,153/255,183/255]

dark_purple = [92/255,35/255,102/255]
light_purple = [158/255,124/255,163/255]

# Load the data from an Excel file
file_path = 'results.xlsx'  # Replace with your file path
sheet_name = 'Sheet4'  # Assuming the data is in Sheet 2
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Extract necessary columns
model_names = data.iloc[:, 0]  # First column: Model Names
mean_mse = data.iloc[:, 2]  # Second column: Mean MSE
std_mse = data.iloc[:, 6]  # Fourth column: Std of MSE

# Create a plot with error bars
plt.figure(figsize=(8, 5))
plt.bar(model_names, mean_mse, yerr=std_mse, capsize=5,color=light_red)
plt.xlabel('Model')
plt.ylabel(r'$R^2$')
# plt.title('Mean MSE of Models with Error Bars for Std of MSE')
plt.xticks(rotation=45)  # Rotate model names for better visibility
plt.tight_layout()  # Adjust layout to make room for label rotation

plt.savefig('r2.png',dpi=600,bbox_inches = 'tight')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define colors
dark_red = [210/255, 0, 0]
light_red = [228/255, 128/255, 128/255]

dark_blue = [71/255, 55/255, 63/255]
light_blue = [154/255, 153/255, 183/255]

dark_purple = [92/255, 35/255, 102/255]
light_purple = [158/255, 124/255, 163/255]

# Load the data from an Excel file
file_path = 'results.xlsx'  # Replace with your file path
sheet_name = 'Sheet5'  # Update the sheet name as needed
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Extract necessary columns
model_names = data.iloc[:, 0]  # First column: Model Names
mean_mse = data.iloc[:, 1]  # Second column: Mean MSE
std_mse = data.iloc[:, 5]  # Third column: Std of MSE
mean_mae = data.iloc[:, 3]  # New: Mean MAE
std_mae = data.iloc[:, 7]  # New: Std of MAE
mean_mape = data.iloc[:, 2]
std_mape = data.iloc[:, 6]
mean_r2 = data.iloc[:, 4]  # New: Mean R2
std_r2 = data.iloc[:, 8]  # New: Std of R2

# Define hatch patterns for each bar group
hatches = ['o', '.', 'x', '+']  # Different hatches for MAE, MAPE, MSE, R2
# Bar positions
x = np.arange(len(model_names))  # the label locations
width = 0.2  # the width of the bars

# Create a plot with error bars
fig, ax1 = plt.subplots()
bars1 = ax1.bar(x - 1.5*width, mean_mae, width, yerr=std_mae, capsize=5, color=light_blue, label='MAE', hatch=hatches[0])
bars2 = ax1.bar(x -0.5*width, mean_mape,width, yerr = std_mape, capsize=5, color = 'orange', label = 'MAPE', hatch=hatches[1] )
bars3 = ax1.bar(x+0.5*width, mean_mse, width, yerr=std_mse, capsize=5, color=light_red, label='MSE', hatch=hatches[2])
ax1.set_ylabel('Error Metrics')
ax1.set_xlabel('Data')
ax1.set_xticks(x)
ax1.set_xticklabels(model_names)
# ax1.legend(loc='upper left')
plt.yscale('log')

# Create a second y-axis for the R2 values
ax2 = ax1.twinx()
bars4 = ax2.bar(x + 1.5*width, mean_r2, width, yerr=std_r2, capsize=5, color=light_purple, label=r'$R^2$', hatch=hatches[3])
ax2.set_ylabel(r'$R^2$')
# ax2.legend(loc='upper right')
plt.ylim(0,1)

# Combine legends
bars = [bars1, bars2, bars3, bars4]
labels = [bar.get_label() for bar in bars]

ax1.legend(bars, labels, loc='upper left')

# Final touches
plt.tight_layout()  # Adjust layout to make room for label rotation
plt.savefig('data_process.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define colors
dark_red = [210/255, 0, 0]
light_red = [228/255, 128/255, 128/255]

dark_blue = [71/255, 55/255, 63/255]
light_blue = [154/255, 153/255, 183/255]

dark_purple = [92/255, 35/255, 102/255]
light_purple = [158/255, 124/255, 163/255]

# Load the data from an Excel file
file_path = 'results.xlsx'  # Replace with your file path
sheet_name = 'Sheet5'  # Update the sheet name as needed
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Extract necessary columns
model_names = data.iloc[:, 0]  # First column: Model Names
mean_mse = data.iloc[:, 1]  # Second column: Mean MSE
std_mse = data.iloc[:, 5]  # Third column: Std of MSE
mean_mae = data.iloc[:, 3]  # New: Mean MAE
std_mae = data.iloc[:, 7]  # New: Std of MAE
mean_mape = data.iloc[:, 2]
std_mape = data.iloc[:, 6]
mean_r2 = data.iloc[:, 4]  # New: Mean R2
std_r2 = data.iloc[:, 8]  # New: Std of R2

# Bar positions
x = np.arange(len(model_names))  # the label locations
width = 0.2  # the width of the bars

# Define hatch patterns for each bar group
hatches = ['o', '.', 'x', '+']  # Different hatches for MAE, MAPE, MSE, R2

# Create a plot with error bars and hatches
fig, ax1 = plt.subplots()
bars1 = ax1.bar(x - 1.5*width, mean_mae, width, yerr=std_mae, capsize=5, color=light_blue, label='MAE', hatch=hatches[0])
bars2 = ax1.bar(x - 0.5*width, mean_mape, width, yerr=std_mape, capsize=5, color='orange', label='MAPE', hatch=hatches[1])
bars3 = ax1.bar(x + 0.5*width, mean_mse, width, yerr=std_mse, capsize=5, color=light_red, label='MSE', hatch=hatches[2])
ax1.set_ylabel('Error Metrics')
ax1.set_xlabel('Data')
ax1.set_xticks(x)
ax1.set_xticklabels(model_names)
plt.yscale('log')

# Create a second y-axis for the R2 values
ax2 = ax1.twinx()
bars4 = ax2.bar(x + 1.5*width, mean_r2, width, yerr=std_r2, capsize=5, color=light_purple, label=r'$R^2$', hatch=hatches[3])
ax2.set_ylabel(r'$R^2$')
plt.ylim(0, 1)

# Combine legends
bars = [bars1, bars2, bars3, bars4]
labels = [bar.get_label() for bar in bars]
ax1.legend(bars, labels, loc='upper left')

# Final touches
plt.tight_layout()  # Adjust layout to make room for label rotation
plt.savefig('data_process_1.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define colors
dark_red = [210/255, 0, 0]
light_red = [228/255, 128/255, 128/255]

dark_blue = [71/255, 55/255, 63/255]
light_blue = [154/255, 153/255, 183/255]

dark_purple = [92/255, 35/255, 102/255]
light_purple = [158/255, 124/255, 163/255]

# Load the data from an Excel file
file_path = 'results.xlsx'  # Replace with your file path
sheet_name = 'Sheet6'  # Update the sheet name as needed
data = pd.read_excel(file_path, sheet_name=sheet_name)

data = pd.read_excel(file_path, sheet_name=sheet_name)

# Extract necessary columns
model_names = data.iloc[:, 0]  # First column: Model Names
mean_mse = data.iloc[:, 1]  # Second column: Mean MSE
std_mse = data.iloc[:, 5]  # Third column: Std of MSE
mean_mae = data.iloc[:, 3]  # New: Mean MAE
std_mae = data.iloc[:, 7]  # New: Std of MAE
mean_mape = data.iloc[:, 2]
std_mape = data.iloc[:, 6]
mean_r2 = data.iloc[:, 4]  # New: Mean R2
std_r2 = data.iloc[:, 8]  # New: Std of R2

# Define hatch patterns for each bar group
hatches = ['o', '.', 'x', '+']  # Different hatches for MAE, MAPE, MSE, R2
# Bar positions
x = np.arange(len(model_names))  # the label locations
width = 0.2  # the width of the bars

# Create a plot with error bars
fig, ax1 = plt.subplots()
bars1 = ax1.bar(x - 1.5*width, mean_mae, width, yerr=std_mae, capsize=5, color=light_blue, label='MAE', hatch=hatches[0])
bars2 = ax1.bar(x -0.5*width, mean_mape,width, yerr = std_mape, capsize=5, color = 'orange', label = 'MAPE', hatch=hatches[1] )
bars3 = ax1.bar(x+0.5*width, mean_mse, width, yerr=std_mse, capsize=5, color=light_red, label='MSE', hatch=hatches[2])
ax1.set_ylabel('Error Metrics')
ax1.set_xlabel('Data')
ax1.set_xticks(x)
ax1.set_xticklabels(model_names)
# ax1.legend(loc='upper left')
plt.yscale('log')

# Create a second y-axis for the R2 values
ax2 = ax1.twinx()
bars4 = ax2.bar(x + 1.5*width, mean_r2, width, yerr=std_r2, capsize=5, color=light_purple, label=r'$R^2$', hatch=hatches[3])
ax2.set_ylabel(r'$R^2$')
# ax2.legend(loc='upper right')
plt.ylim(0,1)

# Combine legends
bars = [bars1, bars2, bars3, bars4]
labels = [bar.get_label() for bar in bars]

ax1.legend(bars, labels, loc='upper left')

# Final touches
plt.tight_layout()  # Adjust layout to make room for label rotation
plt.savefig('loss.png', dpi=600, bbox_inches='tight')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df_original = pd.read_csv('train.csv')
df_transformed = pd.read_csv('train_copy.csv')


df_transformed['pci'] = df_transformed['pci'].apply(lambda x: 0 if x < 0 else x)

def reduce_pci_100(df):
    # Find the rows where pci is 100
    pci_100 = df[df['pci'] == 100]
    # Reduce the number of these rows by a factor of 10
    reduced_pci_100 = pci_100.sample(frac=0.1, random_state=1)
    # Drop the original pci=100 rows
    df = df[df['pci'] != 100]
    # Append the reduced number of pci=100 rows
    df = pd.concat([df, reduced_pci_100], ignore_index=True)
    return df

df_transformed = reduce_pci_100(df_transformed)
# Plotting both distributions on the same plot
number_of_pci_0 = (df_transformed['pci'] == 1).sum()
# print(number_of_pci_0)
# Plotting the original data in a separate plot
plt.figure()
sns.histplot(df_original['pci'], bins=50, kde=True, label='Original pci', color=dark_red, stat="density", element="step", fill=True)
plt.title('Original Dataset')
plt.xlabel('PCI')
plt.ylabel('Density')
# plt.legend()
# plt.show()
plt.savefig('original dataset.png',dpi=600,bbox_inches = 'tight')

# Plotting the transformed data in a separate plot
plt.figure()
sns.histplot(df_transformed['pci'], bins=50, kde=True, label='Transformed pci', color=dark_blue, stat="density", element="step", fill=True)
plt.title('After Processing')
plt.xlabel('PCI')
plt.ylabel('Density')
# plt.xlim(0,100)
# plt.legend()
# plt.show()
plt.savefig('after processing.png',dpi=600,bbox_inches = 'tight')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Load the data
df_original = pd.read_csv('train.csv')
df_transformed = pd.read_csv('train_copy.csv')

# Apply the transformation
df_transformed['pci'] = df_transformed['pci'].apply(lambda x: 0 if x < 0 else x)

def reduce_pci_100(df):
    pci_100 = df[df['pci'] == 100]
    reduced_pci_100 = pci_100.sample(frac=0.1, random_state=1)
    df = df[df['pci'] != 100]
    df = pd.concat([df, reduced_pci_100], ignore_index=True)
    return df

df_transformed = reduce_pci_100(df_transformed)

# Plot original data
plt.figure()
original_hist = sns.histplot(df_original['pci'], bins=50, kde=True, color='darkred', stat="density", element="step", fill=True)
# plt.title('Original Dataset')
plt.xlabel('PCI')
plt.ylabel('Density')
plt.savefig('original_dataset.png', dpi=600, bbox_inches='tight')

# Find the highest bar in the original plot
original_counts, original_edges = np.histogram(df_original['pci'], bins=50)
original_max_count = original_counts.max()
print(f'Highest bar in the original plot: {original_max_count}')

# Plot transformed data
plt.figure()
transformed_hist = sns.histplot(df_transformed['pci'], bins=50, kde=True, color='darkblue', stat="density", element="step", fill=True)
plt.title('After Processing')
plt.xlabel('PCI')
plt.ylabel('Density')
plt.savefig('after_processing.png', dpi=600, bbox_inches='tight')

# Find the highest bar in the transformed plot
transformed_counts, transformed_edges = np.histogram(df_transformed['pci'], bins=50)
transformed_max_count = transformed_counts.max()
print(f'Highest bar in the transformed plot: {transformed_max_count}')

# Plot overlapping histograms
plt.figure()
sns.histplot(df_original['pci'], bins=50, kde=True, color='darkred', stat="density", element="step", fill=True, label='Original Data')
sns.histplot(df_transformed['pci'], bins=50, kde=True, color='darkblue', stat="density", element="step", fill=True, label='Preprocessed Data')
# plt.title('Overlapping Histograms')
plt.xlabel('PCI')
plt.ylabel('Density')
plt.legend(loc=2)
plt.savefig('overlapping_histograms.png', dpi=600, bbox_inches='tight')
plt.show()
# Out:
# Highest bar in the original plot: 2379
# Highest bar in the transformed plot: 293

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Load the data
df_original = pd.read_csv('train.csv')
df_transformed = pd.read_csv('train_copy.csv')

# Apply the transformation
df_transformed['pci'] = df_transformed['pci'].apply(lambda x: 0 if x < 0 else x)

def reduce_pci_100(df):
    pci_100 = df[df['pci'] == 100]
    reduced_pci_100 = pci_100.sample(frac=0.1, random_state=1)
    df = df[df['pci'] != 100]
    df = pd.concat([df, reduced_pci_100], ignore_index=True)
    return df

df_transformed = reduce_pci_100(df_transformed)

# Plot original data
plt.figure()
original_hist = sns.histplot(df_original['pci'], bins=50, kde=True, color='darkred', stat="density", element="step", fill=True)
plt.title('Original Dataset')
plt.xlabel('PCI')
plt.ylabel('Density')
plt.savefig('original_dataset.png', dpi=600, bbox_inches='tight')

# Find the highest bar in the original plot
original_counts, original_edges = np.histogram(df_original['pci'], bins=50)
original_max_count = original_counts.max()
original_max_index = original_counts.argmax()
original_bin_range = (original_edges[original_max_index], original_edges[original_max_index + 1])
print(f'Highest bar in the original plot: {original_max_count} in the bin range {original_bin_range}')

# Plot transformed data
plt.figure()
transformed_hist = sns.histplot(df_transformed['pci'], bins=50, kde=True, color='darkblue', stat="density", element="step", fill=True)
plt.title('After Processing')
plt.xlabel('PCI')
plt.ylabel('Density')
plt.savefig('after_processing.png', dpi=600, bbox_inches='tight')

# Find the highest bar in the transformed plot
transformed_counts, transformed_edges = np.histogram(df_transformed['pci'], bins=50)
transformed_max_count = transformed_counts.max()
transformed_max_index = transformed_counts.argmax()
transformed_bin_range = (transformed_edges[transformed_max_index], transformed_edges[transformed_max_index + 1])
print(f'Highest bar in the transformed plot: {transformed_max_count} in the bin range {transformed_bin_range}')

# Plot overlapping histograms
plt.figure()
sns.histplot(df_original['pci'], bins=50, kde=True, color='darkred', stat="density", element="step", fill=True, label='Original pci')
sns.histplot(df_transformed['pci'], bins=50, kde=True, color='darkblue', stat="density", element="step", fill=True, label='Transformed pci')
plt.title('Overlapping Histograms')
plt.xlabel('PCI')
plt.ylabel('Density')
plt.legend()
plt.savefig('overlapping_histograms.png', dpi=600, bbox_inches='tight')
plt.show()
# Out:
# Highest bar in the original plot: 2379 in the bin range (97.84, 100.0)
# Highest bar in the transformed plot: 792 in the bin range (64.0, 66.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
data = pd.read_csv('prediction_results_MSE.csv')

# Assuming 'actual' and 'predicted' are the column names
x = data['Actual PCI']
y = data['Predicted PCI']

# Create scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x, y,label='MSELoss')
# plt.title('Scatter plot of Actual vs. Predicted')
plt.xlabel('Actual PCI')
plt.ylabel('Predicted PCI')


data1 = pd.read_csv('prediction_results.csv')

# Assuming 'actual' and 'predicted' are the column names
x1 = data1['Actual PCI']
y1 = data1['Predicted PCI']

# Create scatter plot
# plt.figure(figsize=(8, 6))
plt.scatter(x1, y1, label='PCILoss',color='orange', marker='x')
# plt.title('Scatter plot of Actual vs. Predicted')
# plt.xlabel('Actual')
# plt.ylabel('Predicted')
plt.legend()
plt.xlim(-1,101)
plt.ylim(-1,101)


# Plot x=y line
plt.plot([min(x.min(), y.min()), max(x.max(), y.max())], [min(x.min(), y.min()), max(x.max(), y.max())], 'r--', lw=2)
plt.savefig('MSEvsPCILoss.png', dpi=600, bbox_inches='tight')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Load the data
df_original = pd.read_csv('train.csv')
df_transformed = pd.read_csv('train_copy.csv')

# Apply the transformation
df_transformed['pci'] = df_transformed['pci'].apply(lambda x: 0 if x < 0 else x)

def reduce_pci_100(df):
    pci_100 = df[df['pci'] == 100]
    reduced_pci_100 = pci_100.sample(frac=0.1, random_state=1)
    df = df[df['pci'] != 100]
    df = pd.concat([df, reduced_pci_100], ignore_index=True)
    return df

df_transformed = reduce_pci_100(df_transformed)

# Plot original data
plt.figure()
sns.histplot(df_original['pci'], bins=50, kde=True, color='darkred',
             stat="density", element="step", fill=True)
plt.xlabel('PCI')
plt.ylabel('Percentage (%)')
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y * 100:.0f}'))
plt.savefig('original_dataset.png', dpi=600, bbox_inches='tight')

# Find the highest bar in the original plot
original_counts, original_edges = np.histogram(df_original['pci'], bins=50)
original_max_count = original_counts.max()
print(f'Highest bar in the original plot: {original_max_count}')

# Plot transformed data
plt.figure()
sns.histplot(df_transformed['pci'], bins=50, kde=True, color='darkblue',
             stat="density", element="step", fill=True)
plt.title('After Processing')
plt.xlabel('PCI')
plt.ylabel('Percentage (%)')
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y * 100:.0f}'))
plt.savefig('after_processing.png', dpi=600, bbox_inches='tight')

# Find the highest bar in the transformed plot
transformed_counts, transformed_edges = np.histogram(df_transformed['pci'], bins=50)
transformed_max_count = transformed_counts.max()
print(f'Highest bar in the transformed plot: {transformed_max_count}')

# Plot overlapping histograms
plt.figure()
sns.histplot(df_original['pci'], bins=50, kde=True, color='darkred',
             stat="density", element="step", fill=True, label='Original Data')
sns.histplot(df_transformed['pci'], bins=50, kde=True, color='darkblue',
             stat="density", element="step", fill=True, label='Preprocessed Data')
plt.xlabel('PCI')
plt.ylabel('Percentage (%)')
plt.legend(loc=2)
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y * 100:.0f}'))
plt.savefig('overlapping_histograms.png', dpi=600, bbox_inches='tight')
plt.show()
# Out:
# Highest bar in the original plot: 2379
# Highest bar in the transformed plot: 293
